# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
result = app('com.gojek.gopay')
print(result['title'])        # Nama aplikasi
print(result['appId'])        # Package name
# Out:
# GoPay: Transfer Pulsa Bills
# com.gojek.gopay

# %%
scrapreview = reviews_all(
    'com.gojek.gopay',           # ID aplikasi
    lang='id',                              # Bahasa ulasan (default: 'en')
    country='id',                           # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT,                # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=8000                             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
import csv

with open('ulasan_gopay.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])

# %%
import pandas as pd

app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_gopay.csv', index=False)

# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df.head(5)
# Out:
#                                reviewId         userName  \
# 0  0cae73fc-8b80-485c-8185-71930ca9902e  Pengguna Google
# 1  feed408f-01f8-4da6-bbd3-13aab4747d7c  Pengguna Google
# 2  5e295fec-8e3b-4084-bceb-9289f0c6e2b9  Pengguna Google
# 3  a38f0670-9576-48ae-964f-945cda28eb80  Pengguna Google
# 4  09e59012-2ca2-4c54-9410-e8d5401ac655  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  saya suka gopay karena murah dan saldo tetap a...      2             43
# 1  GoPay emang terbaik! Banyak banget promo dan c...      5             95
# ...

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21073 entries, 0 to 21072
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              21073 non-null  object
#  1   userName              21073 non-null  object
#  2   userImage             21073 non-null  object
#  3   content               21073 non-null  object
#  4   score                 21073 non-null  int64
#  5   thumbsUpCount         21073 non-null  int64
#  6   reviewCreatedVersion  15630 non-null  object
#  7   at                    21073 non-null  datetime64[ns]
#  8   replyContent          18480 non-null  object
#  9   repliedAt             18480 non-null  datetime64[ns]
#  10  appVersion            15630 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.8+ MB
